# %% [markdown]
# <a href="https://colab.research.google.com/github/BureddySaiPoojitha/Module4_AllLabs_AIML_-/blob/main/MODULE4_LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODULE_4 : PERCEPTRON AND GRADIENT DESCENT
#
# Lab 1 : Perceptron

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
X=np.array([[-2,5],[2,9],[3,1],[5,9],[3,7]])

# %%
X=np.array([[-1,3,7],[3,6,2],[9,5,1],[9,3,0],[3,5,-1]])

# %%
y=np.array([-1,-1,1,1,2])

# %%
for d, sample in enumerate(X):
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)
plt.plot([-2, 6], [6, 0.5])

# %%
def perceptron_algo(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    epochs = 10

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                w = w + eta * X[i] * Y[i]
    return w

# %%
def perceptron_algo_plot(X, Y):
    '''
    train perceptron and plot the total loss in each epoch.

    :param X: data samples
    :param Y: data labels
    :return: weight vector as a numpy array
    '''
    w = np.zeros(len(X[0]))
    eta = 1
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

# %%
w = perceptron_algo_plot(X, y)

# %%
for d, sample in enumerate(X):
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

plt.scatter(2, 2, s=120, marker='_', linewidths=2, color='yellow')
plt.scatter(4, 3, s=120, marker='+', linewidths=2, color='blue')

x2 = [w[0], w[1], -w[1], w[0]]
x3 = [w[0], w[1], w[1], -w[0]]

x2x3 = np.array([x2, x3])
X, Y, U, V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X, Y, U, V, scale=1, color='blue')

# %%
X = np.array([
    [-5, 7, -1],
    [3, 9, -1],
    [2, 4, -1],
    [6, 8, -1],
    [3, 2, -1],
])

# %%
y = np.array([-1, -1, 1, -1, -1])

# %%
print(perceptron_algo_plot(X, y))
# Out:
# [-4. -4. -8.]

# %% [markdown]
# # **QUESTIONS**

# %% [markdown]
# 1.  Consider the following dataset where x = (x1, x2) ∈ {0, 1}× {0, 1}, y ∈ {−, +}. Note that this dataset is corresponding to the boolean function “AND” over the 2-bit binary input.
#
#   Suppose we are training a Perceptron to learn on this dataset and we initialize w0 = 0 and b0 = 0.
#
#   Please i) answer if this dataset is learnable by Perceptron, and ii) if so, write down the weights update procedure for each iteration; if not, explain why

# %% [markdown]
# Yes, the AND dataset is learnable because it is linearly separable. A Perceptron can find a decision boundary
# x1+x2=1
#  after weight updates, correctly classifying all samples.

# %% [markdown]
# 2.  Extending AND to any boolean functions over a 2-bit binary input, where we have (2^2)^2 = 16 possible distinct boolean functions in total, among which how many of them can be learnable by a Perceptron?
#
#    Please also write down the truth table(s) of the boolean functions that are not learnable, if there are any.

# %% [markdown]
# Out of 16 Boolean functions, 14 are learnable as they are linearly separable. The XOR and XNOR functions are not learnable because they are non-linearly separable.
